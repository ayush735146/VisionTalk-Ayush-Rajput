# %% [markdown]
# # VisionTalk: Image Captioning with CNN + LSTM
# **BY AYUSH RAJPUT**
#
# This notebook provides a guided execution of the VisionTalk project.

# %%
# !python download_flickr8k.py

# %%
# !python feature_extractor.py

# %%
# !python train.py --epochs 20

# %%
# !python evaluate.py
